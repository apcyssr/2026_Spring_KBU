# %% [markdown]
# <a href="https://colab.research.google.com/github/apcyssr/2026_Spring_KBU/blob/main/20260429_Data_APICHAYA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import sympy as sp

# %%
# 1. 기호 변수 및 데이터 정의 (กำหนดตัวแปรและข้อมูล)
w, b = sp.symbols('w b')
x_vals = [1, 2, 3, 4, 5]
y_vals = [2.1, 3.9, 6.2, 8.1, 10.1]
n = len(x_vals)

# 2. 손실 함수 (MSE) 수식화 (สร้างสูตร Loss Function)
loss = 0
for i in range(n):
    prediction = w * x_vals[i] + b
    loss += (prediction - y_vals[i])**2
loss = loss / n # MSE
print(loss)

# 3. 기울기(w)와 절편(b)에 대한 편미분 (หาอนุพันธ์ย่อยเทียบกับ w และ b)
diff_w = sp.diff(loss, w)
diff_b = sp.diff(loss, b)
print(f"w에 대한 미분식: {diff_w}")
print(f"b에 대한 미분식: {diff_b}")

# 4. 미분값이 0이 되는 연립 방정식 풀이 (แก้สมการหาจุดที่อนุพันธ์เป็น 0)
solution = sp.solve((diff_w, diff_b), (w, b))
print(f"최적의 기울기 (w): {solution[w]:.4f}")
print(f"최적의 절편 (b): {solution[b]:.4f}")

# 5. 최적의 선형 회귀 방정식 출력
print(f"\n최적의 선형 회귀 방정식: y = {solution[w]:.4f}x + {solution[b]:.4f}")
# Out:
# (b + w - 2.1)**2/5 + (b + 2*w - 3.9)**2/5 + (b + 3*w - 6.2)**2/5 + (b + 4*w - 8.1)**2/5 + (b + 5*w - 10.1)**2/5
# w에 대한 미분식: 6*b + 22*w - 44.56
# b에 대한 미분식: 2*b + 6*w - 12.16
# 최적의 기울기 (w): 2.0200
# 최적의 절편 (b): 0.0200
#
# 최적의 선형 회귀 방정식: y = 2.0200x + 0.0200

# %%
import sympy

# 1. 변수 및 함수 선언 (ประกาศตัวแปรและฟังก์ชัน)
a, b, x, y = sympy.symbols('a b x y')
L = sympy.Rational(1, 2) * (a + b * x - y)**2

# 2. 편미분 계산 (คำนวณอนุพันธ์ย่อย)
grad_a = sympy.diff(L, a) # a에 대해 편미분
grad_b = sympy.diff(L, b) # b에 대해 편미분

# 3. 결과 출력 (แสดงผลลัพธ์)
print(f"dL/d_a: {grad_a}")
print(f"dL/d_b : {grad_b}")
# Out:
# dL/d_a: a + b*x - y
# dL/d_b : x*(a + b*x - y)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# เตรียมข้อมูล
X, y, _ = make_regression(n_samples=50, n_features=1, noise=50, coef=True, random_state=11)
X, y = X.squeeze(), y.squeeze()

alpha, beta, data = 0, 0, []

# Training Loop
for _ in range(50): # Epochs
    for row in range(len(X)):
        y_hat = alpha + beta * X[row]
        error = y_hat - y[row]

        # Update parameters
        alpha -= 0.01 * error
        beta  -= 0.01 * error * X[row]
        data.append([alpha, beta, y_hat, y[row], error])

# การแสดงผลด้วย Plot
data = pd.DataFrame(data, columns=['alpha', 'beta', 'y_hat', 'y', 'error'])
last_epoch = data.iloc[-len(X):].reset_index(drop=True)
final = last_epoch[['y', 'y_hat', 'error']]

plt.figure(figsize=(8, 5))
plt.scatter(X, y, s=30, label='Actual')
plt.scatter(X, final['y_hat'], s=30, color='orange', label='Predicted')
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.title("Gradient Descent: Actual vs Predicted")
plt.show()

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
result = np.dot(a, b) # หรือ a @ b
print(result)
# Out:
# 32

# %%
A = np.array([[1, 2], [3, 4]])
x = np.array([5, 6])
result = np.dot(A, x) # หรือ A @ x
print(result)
# Out:
# [17 39]

# %%
a = np.array([0.0, 10.0, 20.0, 30.0])
b = np.array([1.0, 2.0, 3.0])
# การบวกข้ามมิติ
result = a[:, np.newaxis] + b
# หรือ
result = a.reshape(-1,1) + b

print (result)
# Out:
# [[ 1.  2.  3.]
#  [11. 12. 13.]
#  [21. 22. 23.]
#  [31. 32. 33.]]

# %%
# ตัวอย่างที่ 1: เวกเตอร์บวกกับสเกลาร์
a = np.array([1.0, 2.0, 3.0])
b = 2.0
print(a * b) # [2.0, 4.0, 6.0]

# ตัวอย่างที่ 2: เมทริกซ์บวกกับเวกเตอร์
a = np.array([[ 0.0,  0.0,  0.0],
              [10.0, 10.0, 10.0],
              [20.0, 20.0, 20.0],
              [30.0, 30.0, 30.0]])
b = np.array([1.0, 2.0, 3.0])
print(a + b)

# ตัวอย่างที่ 3: การเพิ่มมิติ (New Axis) เพื่อคำนวณ
a = np.array([0.0, 10.0, 20.0, 30.0])
b = np.array([1.0, 2.0, 3.0])

result1 = a[:, np.newaxis] + b
result2 = a.reshape(-1, 1) + b
# Out:
# [2. 4. 6.]
# [[ 1.  2.  3.]
#  [11. 12. 13.]
#  [21. 22. 23.]
#  [31. 32. 33.]]

# %%
from numpy import array, argmin, sqrt, sum

observation = array([111.0, 188.0])
codes = array([[102.0, 203.0],
               [132.0, 193.0],
               [45.0, 155.0],
               [57.0, 173.0]])

# คำนวณความต่าง (เกิด Broadcasting ที่นี่)
diff = codes - observation
print(f"The difference is: {diff}")

# คำนวณระยะห่าง Euclidean Distance
dist = sqrt(sum(diff**2, axis=-1))
print(f"The distance is: {dist}")

# หา Index ของจุดที่ใกล้ที่สุด
nearest_index = argmin(dist)
print(f"The index of the nearest point is: {nearest_index}")
# Out:
# The difference is: [[ -9.  15.]
#  [ 21.   5.]
#  [-66. -33.]
#  [-54. -15.]]
# The distance is: [17.49285568 21.58703314 73.79024326 56.04462508]
# The index of the nearest point is: 0

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.datasets import make_regression

# เตรียมข้อมูล
X, y, _ = make_regression(n_samples=50, n_features=1, noise=15, coef=True, random_state=11)

# เรียกใช้ Model
reg = SGDRegressor(max_iter=1000, tol=1e-3)
reg.fit(X, y)

print(f"Coefficients: {reg.coef_}")
print(f"Intercept: {reg.intercept_}")
# Out:
# Coefficients: [80.24667327]
# Intercept: [0.23606064]

# %%
import torch

# %%
# Input: A standard Python list
data = [[1, 2, 3], [4, 5, 6]]
my_tensor = torch.tensor(data)

print(my_tensor)
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
import torch

# Input: A shape tuple (2 rows, 3 columns)
shape = (2, 3)

ones = torch.ones(shape)
zeros = torch.zeros(shape)
random = torch.randn(shape)

print(f"Random Tensor:\n {random}")
# Out:
# Random Tensor:
#  tensor([[ 0.0493,  1.7485,  0.3250],
#         [-1.0054,  0.3164,  1.5679]])

# %%
import torch

# Input: A 'template' tensor
template = torch.tensor([[1, 2], [3, 4]])

# Create a new tensor with the same properties
rand_like = torch.randn_like(template, dtype=torch.float)

print(f"Template Tensor:\n {template}\n")
print(f"Randn_like Tensor:\n {rand_like}")
# Out:
# Template Tensor:
#  tensor([[1, 2],
#         [3, 4]])
#
# Randn_like Tensor:
#  tensor([[-0.7584, -0.9466],
#         [ 0.4556,  1.0014]])

# %%
import torch

# สร้าง Tensor ต้นแบบ (Template)
template = torch.tensor([[1, 2], [3, 4]])

# สร้าง Tensor ใหม่ที่มี "ขนาดเท่าต้นแบบ" แต่สุ่มค่าใหม่
rand_like = torch.randn_like(template, dtype=torch.float)

print(f"Template Tensor:\n {template}\n")
print(f"Randn_like Tensor:\n {rand_like}")
# Out:
# Template Tensor:
#  tensor([[1, 2],
#         [3, 4]])
#
# Randn_like Tensor:
#  tensor([[-0.5611,  0.8762],
#         [-0.3968, -0.2835]])

# %%
import torch

# A standard data tensor (โดยปกติเราไม่เก็บ gradient สำหรับข้อมูล input)
x_data = torch.tensor([[1., 2.], [3., 4.]])

# A parameter tensor (เราต้องการคำนวณ gradients เพื่อปรับค่า weights)
w = torch.tensor([[1.0], [2.0]], requires_grad=True)

print(f"Data tensor requires_grad: {x_data.requires_grad}")
print(f"Parameter tensor requires_grad: {w.requires_grad}")
# Out:
# Data tensor requires_grad: False
# Parameter tensor requires_grad: True

# %%
import torch

# สร้าง Parameter tensors 3 ตัวที่รองรับการหา Gradient
a = torch.tensor(2.0, requires_grad=True)
b = torch.tensor(3.0, requires_grad=True)
x = torch.tensor(4.0, requires_grad=True)
y = torch.tensor(5.0, requires_grad=True)

# เริ่มสร้าง Graph ด้วย Operation แรก: การบวก
y = a + b  # ผลลัพธ์จะเป็น 5.0 (2.0 + 3.0)
z = x * y

print(f"Result y: {y}")
print(f"Result z: {z}")
# Out:
# Result y: 5.0
# Result z: 20.0

# %%
# z ถูกสร้างจากการคูณ (multiplication)
print(f"grad_fn for z: {z.grad_fn}")

# y ถูกสร้างจากการบวก (addition)
print(f"grad_fn for y: {y.grad_fn}")

# a ถูกสร้างโดย user (ใบไม้ของกราฟ) ไม่ได้เกิดจาก operation ใดๆ
print(f"grad_fn for a: {a.grad_fn}")
# Out:
# grad_fn for z: <MulBackward0 object at 0x7a0986ef8910>
# grad_fn for y: <AddBackward0 object at 0x7a0985778b80>
# grad_fn for a: None

# %%
import torch

# Matrix ตัวแรก ขนาด (2, 3) -> 2 แถว 3 คอลัมน์
m1 = torch.tensor([[1, 2, 3], [4, 5, 6]])

# Matrix ตัวที่สอง ขนาด (3, 2) -> 3 แถว 2 คอลัมน์
m2 = torch.tensor([[7, 8], [9, 10], [11, 12]])

# คูณเมทริกซ์ด้วยสัญลักษณ์ @
# ผลลัพธ์ที่ได้จะมีขนาด (2, 2)
matrix_product = m1 @ m2

print(matrix_product)
# Out:
# tensor([[ 58,  64],
#         [139, 154]])
